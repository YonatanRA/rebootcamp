# %% [markdown]
# # Codigos de barras (supply chain)
#
#
# ### Base de datos
#
#
# Se rellena una base de datos de Postgres con datos guardados en csv.

# %%
# librerias

import pandas as pd
pd.set_option('display.max_columns', None)

from lib.sql_db import ToSQL
from sqlalchemy import create_engine, Column, Integer, Text
from sqlalchemy.orm import sessionmaker
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import DDL

import warnings
warnings.simplefilter('ignore')

# %%
df=pd.read_csv('../datasets/shoes.csv')

df.head()
# Out:
#                      id             dateAdded           dateUpdated asins  \
# 0  AVpfEf_hLJeJML431ueH  2015-05-04T12:13:08Z  2018-01-29T04:38:43Z   NaN
# 1  AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
# 2  AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
# 3  AVpjXyCc1cnluZ0-V-Gj  2017-01-27T01:25:56Z  2018-01-04T11:52:35Z   NaN
# 4  AVphGKLPilAPnD_x1Nrm  2017-01-27T01:25:56Z  2018-01-18T03:55:18Z   NaN
#
#          brand                                         categories  \
# 0  Naturalizer  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 1     MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 2     MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 3     MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 4     MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
#
#   primaryCategories                          colors                 dimension  \
# 0             Shoes  Silver,Cream Watercolor Floral                       NaN
# 1             Shoes                            Grey                       NaN
# 2             Shoes                            Grey                       NaN
# 3       Shoes,Shoes                           Black  6.0 in x 6.0 in x 1.0 in
# 4             Shoes                            Grey  6.0 in x 6.0 in x 1.0 in
#
#             ean                                          imageURLs  \
# 0           NaN  https://i5.walmartimages.com/asr/861ca6cf-fa55...
# 1  3.397705e+10  https://i5.walmartimages.com/asr/421de5d5-3a74...
# 2  3.397705e+10  https://i5.walmartimages.com/asr/421de5d5-3a74...
# 3  3.397705e+10  https://i5.walmartimages.com/asr/950d38a5-0113...
# 4  3.397705e+10  https://i5.walmartimages.com/asr/5e137bc3-c900...
#
#                                                 keys manufacturer  \
# 0  naturalizer/47147sc022,017136472311,womensnatu...          NaN
# 1  mukluks/00173650206,033977045743,muklukswomens...     Muk Luks
# 2  mukluks/00173650206,033977045743,muklukswomens...     Muk Luks
# 3  033977045903,muklukswomensdawnsuedescuffslippe...     Muk Luks
# 4  mukluks/00173660206,033977045958,0033977045958...          NaN
#
#   manufacturerNumber                                               name  \
# 0         47147SC022  Naturalizer Danya Women N/S Open Toe Synthetic...
# 1       0017365020-6                MUK LUKS Womens Jane Suede Moccasin
# 2       0017365020-6                MUK LUKS Womens Jane Suede Moccasin
# 3       0017366001-6           MUK LUKS Womens Dawn Suede Scuff Slipper
# 4       0017366020-6           MUK LUKS Womens Dawn Suede Scuff Slipper
#
#    prices.amountMax  prices.amountMin prices.availability        prices.color  \
# 0             55.99             55.99                 NaN  UWomens  M Regular
# 1             47.00             35.25            In Stock                Grey
# 2             35.25             35.25            In Stock                Grey
# 3             24.75             24.75            In Stock               Black
# 4             33.00             30.39            In Stock                Grey
#
#   prices.condition prices.currency      prices.dateAdded  \
# 0              NaN             USD  2017-03-28T11:40:25Z
# 1              New             USD  2018-01-03T05:21:54Z
# 2              New             USD  2017-12-06T05:02:42Z
# 3              New             USD  2018-01-04T11:52:35Z
# 4              New             USD  2017-12-04T21:35:47Z
#
#                                      prices.dateSeen  prices.isSale  \
# 0  2017-03-25T09:19:24.819Z,2017-03-25T09:19:19.600Z          False
# 1  2017-12-08T14:24:00.000Z,2017-11-01T02:52:00.000Z           True
# 2  2017-11-10T15:11:00.000Z,2017-11-18T08:00:00.000Z          False
# 3                           2017-12-07T16:37:00.000Z          False
# 4                           2017-11-17T21:15:00.000Z           True
#
#     prices.merchant prices.offer  prices.returnPolicy prices.shipping  \
# 0     Overstock.com          NaN                  NaN             NaN
# 1       Walmart.com          NaN                  NaN        Standard
# 2  Slippers Dot Com          NaN                  NaN           Value
# 3  Slippers Dot Com          NaN                  NaN           Value
# 4       Walmart.com          NaN                  NaN       Expedited
#
#   prices.size                                  prices.sourceURLs  \
# 0           S  https://www.overstock.com/Clothing-Shoes/Women...
# 1           6  https://www.walmart.com/ip/MUK-LUKS-Womens-Jan...
# 2           6  https://www.walmart.com/ip/MUK-LUKS-Womens-Jan...
# 3           6  https://www.walmart.com/ip/MUK-LUKS-Womens-Daw...
# 4           6  https://www.walmart.com/ip/MUK-LUKS-Womens-Daw...
#
#                                                sizes  \
# 0  6W,9W,7.5W,12W,8.5M,9N,9M,9.5M,10.5M,10W,8.5W,...
# 1                                         10,7,6,9,8
# 2                                         10,7,6,9,8
# 3                                         10,7,6,9,8
# 4                                         10,7,6,9,8
#
#                                           sourceURLs           upc weight
# 0  https://www.walmart.com/ip/Naturalizer-Danya-W...  017136472311    NaN
# 1  https://www.walmart.com/ip/MUK-LUKS-Womens-Jan...  033977045743    NaN
# 2  https://www.walmart.com/ip/MUK-LUKS-Womens-Jan...  033977045743    NaN
# 3  https://www.walmart.com/ip/MUK-LUKS-Womens-Daw...  033977045903    NaN
# 4  https://www.walmart.com/ip/MUK-LUKS-Womens-Daw...  033977045958    NaN

# %%
df.columns
# Out:
# Index(['id', 'dateAdded', 'dateUpdated', 'asins', 'brand', 'categories',
#        'primaryCategories', 'colors', 'dimension', 'ean', 'imageURLs', 'keys',
#        'manufacturer', 'manufacturerNumber', 'name', 'prices.amountMax',
#        'prices.amountMin', 'prices.availability', 'prices.color',
#        'prices.condition', 'prices.currency', 'prices.dateAdded',
#        'prices.dateSeen', 'prices.isSale', 'prices.merchant', 'prices.offer',
#        'prices.returnPolicy', 'prices.shipping', 'prices.size',
#        'prices.sourceURLs', 'sizes', 'sourceURLs', 'upc', 'weight'],
#       dtype='object')

# %%
# seleccion de datos

df=df[['brand', 'colors', 'sizes', 'prices.amountMax', 'imageURLs', 'ean', 'upc']]
df.head()
# Out:
#          brand                          colors  \
# 0  Naturalizer  Silver,Cream Watercolor Floral
# 1     MUK LUKS                            Grey
# 2     MUK LUKS                            Grey
# 3     MUK LUKS                           Black
# 4     MUK LUKS                            Grey
#
#                                                sizes  prices.amountMax  \
# 0  6W,9W,7.5W,12W,8.5M,9N,9M,9.5M,10.5M,10W,8.5W,...             55.99
# 1                                         10,7,6,9,8             47.00
# 2                                         10,7,6,9,8             35.25
# 3                                         10,7,6,9,8             24.75
# 4                                         10,7,6,9,8             33.00
#
#                                            imageURLs           ean  \
# 0  https://i5.walmartimages.com/asr/861ca6cf-fa55...           NaN
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
# 2  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
# 3  https://i5.walmartimages.com/asr/950d38a5-0113...  3.397705e+10
# 4  https://i5.walmartimages.com/asr/5e137bc3-c900...  3.397705e+10
#
#             upc
# 0  017136472311
# 1  033977045743
# 2  033977045743
# 3  033977045903
# 4  033977045958

# %%
# quita nan

df=df.dropna().reset_index()
df.head()
# Out:
#    index      brand       colors       sizes  prices.amountMax  \
# 0      1   MUK LUKS         Grey  10,7,6,9,8             47.00
# 1      2   MUK LUKS         Grey  10,7,6,9,8             35.25
# 2      3   MUK LUKS        Black  10,7,6,9,8             24.75
# 3      4   MUK LUKS         Grey  10,7,6,9,8             33.00
# 4      5  Soft Ones  Brown Tweed  5,6.5,9,11             14.00
#
#                                            imageURLs           ean  \
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
# 2  https://i5.walmartimages.com/asr/950d38a5-0113...  3.397705e+10
# 3  https://i5.walmartimages.com/asr/5e137bc3-c900...  3.397705e+10
# 4  https://i5.walmartimages.com/asr/7b979ba6-fa0a...  3.397705e+10
#
#             upc
# 0  033977045743
# 1  033977045743
# 2  033977045903
# 3  033977045958
# 4  033977052222

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 664 entries, 0 to 663
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             664 non-null    int64
#  1   brand             664 non-null    object
#  2   colors            664 non-null    object
#  3   sizes             664 non-null    object
#  4   prices.amountMax  664 non-null    float64
#  5   imageURLs         664 non-null    object
#  6   ean               664 non-null    float64
#  7   upc               664 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 41.6+ KB

# %%
df=df.drop(columns=['index'])
df.head()
# Out:
#        brand       colors       sizes  prices.amountMax  \
# 0   MUK LUKS         Grey  10,7,6,9,8             47.00
# 1   MUK LUKS         Grey  10,7,6,9,8             35.25
# 2   MUK LUKS        Black  10,7,6,9,8             24.75
# 3   MUK LUKS         Grey  10,7,6,9,8             33.00
# 4  Soft Ones  Brown Tweed  5,6.5,9,11             14.00
#
#                                            imageURLs           ean  \
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
# 2  https://i5.walmartimages.com/asr/950d38a5-0113...  3.397705e+10
# 3  https://i5.walmartimages.com/asr/5e137bc3-c900...  3.397705e+10
# 4  https://i5.walmartimages.com/asr/7b979ba6-fa0a...  3.397705e+10
#
#             upc
# 0  033977045743
# 1  033977045743
# 2  033977045903
# 3  033977045958
# 4  033977052222

# %% [markdown]
# **limpieza tallas y color de zapato**

# %%
df.sizes[0]
# Out:
# '10,7,6,9,8'

# %%
df.colors.tail()
# Out:
# 659    Turquo,Black,Yellow,Navy,Natural,Coral,Pewter
# 660    Turquo,Black,Yellow,Navy,Natural,Coral,Pewter
# 661    Turquo,Black,Yellow,Navy,Natural,Coral,Pewter
# 662    Turquo,Black,Yellow,Navy,Natural,Coral,Pewter
# 663    Turquo,Black,Yellow,Navy,Natural,Coral,Pewter
# Name: colors, dtype: object

# %%
df.sizes=df.sizes.apply(lambda x: x.split(','))
df.colors=df.colors.apply(lambda x: x.split(','))

df.head()
# Out:
#        brand         colors             sizes  prices.amountMax  \
# 0   MUK LUKS         [Grey]  [10, 7, 6, 9, 8]             47.00
# 1   MUK LUKS         [Grey]  [10, 7, 6, 9, 8]             35.25
# 2   MUK LUKS        [Black]  [10, 7, 6, 9, 8]             24.75
# 3   MUK LUKS         [Grey]  [10, 7, 6, 9, 8]             33.00
# 4  Soft Ones  [Brown Tweed]   [5, 6.5, 9, 11]             14.00
#
#                                            imageURLs           ean  \
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
# 2  https://i5.walmartimages.com/asr/950d38a5-0113...  3.397705e+10
# 3  https://i5.walmartimages.com/asr/5e137bc3-c900...  3.397705e+10
# 4  https://i5.walmartimages.com/asr/7b979ba6-fa0a...  3.397705e+10
#
#             upc
# 0  033977045743
# 1  033977045743
# 2  033977045903
# 3  033977045958
# 4  033977052222

# %%
# un registro por talla y color

df=df.explode('sizes').reset_index().drop(columns=['index'])
df=df.explode('colors').reset_index().drop(columns=['index'])

df.head()
# Out:
#       brand colors sizes  prices.amountMax  \
# 0  MUK LUKS   Grey    10              47.0
# 1  MUK LUKS   Grey     7              47.0
# 2  MUK LUKS   Grey     6              47.0
# 3  MUK LUKS   Grey     9              47.0
# 4  MUK LUKS   Grey     8              47.0
#
#                                            imageURLs           ean  \
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
# 2  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
# 3  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
# 4  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
#
#             upc
# 0  033977045743
# 1  033977045743
# 2  033977045743
# 3  033977045743
# 4  033977045743

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   brand             41188 non-null  object
#  1   colors            41188 non-null  object
#  2   sizes             41188 non-null  object
#  3   prices.amountMax  41188 non-null  float64
#  4   imageURLs         41188 non-null  object
#  5   ean               41188 non-null  float64
#  6   upc               41188 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 2.2+ MB

# %% [markdown]
# **codigos numericos ean**

# %%
codigo=pd.read_csv('../datasets/upc_corpus.csv')
codigo.head(20)
# Out:
#              ean                                               name
# 0   725177540363  Belle and The Yank 1/4" - 20 TPI x 90mm Hex Dr...
# 1   725177540370  Belle and The Yank 1/4" - 20 TPI x 120mm Hex D...
# 2   797776092321       Eazel Wines 750ml Red Wine Eazel Shiraz 2014
# 3   701197194311  IsyLei lilla IsyLei All-In-One, lilla - Cono L...
# 4   797776110773                    MsConscious 370g Skinny Granola
# 5   797776110797                      MsConscious 370g City Granola
# 6   797776110803                  MsConscious 370g Euphoria Granola
# 7   797776110780            MsConscious 430g Fitness Junkie Granola
# 8   701197247475              Wiuep Co 100ml Wiuep Denim Mist 100mL
# 9   701197247482              Wiuep Co 200mL Wiuep Denim Mist 200mL
# 10  701197247505          Wiuep Co 500mL Wiuep Denim Solution 500mL
# 11  701197247499          Wiuep Co 200mL Wiuep Denim Solution 200mL
# 12  797776111046                               KYROENT Pray/What If
# 13  797776111022                Easy Poop BAgs black Easy Poop Bags
# 14  797776111039                Easy Poop bags black Easy Poop Bags
# 15           NaN                                        Graco 250dc
# 16  797776111084  Vivat Music Foundation CD DigiPak 140 x 125 x ...
# 17  799439792487                 We Are Kindred 6 Luella Leaf Dress
# 18  799439792494                 We Are Kindred 8 Luella Leaf Dress
# 19  799439792500                We Are Kindred 10 Luella Leaf Dress

# %%
codigo=codigo.dropna().reset_index()

# %%
codigo.ean
# Out:
# 0          725177540363
# 1          725177540370
# 2          797776092321
# 3          701197194311
# 4          797776110773
#                ...
# 1045880     52569744970
# 1045881     52569749616
# 1045882     52569751183
# 1045883     52569755860
# 1045884     52569758373
# Name: ean, Length: 1045885, dtype: object

# %%
df.ean=codigo.ean.iloc[0:len(df)]

df.head()
# Out:
#       brand colors sizes  prices.amountMax  \
# 0  MUK LUKS   Grey    10              47.0
# 1  MUK LUKS   Grey     7              47.0
# 2  MUK LUKS   Grey     6              47.0
# 3  MUK LUKS   Grey     9              47.0
# 4  MUK LUKS   Grey     8              47.0
#
#                                            imageURLs           ean  \
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540370
# 2  https://i5.walmartimages.com/asr/421de5d5-3a74...  797776092321
# 3  https://i5.walmartimages.com/asr/421de5d5-3a74...  701197194311
# 4  https://i5.walmartimages.com/asr/421de5d5-3a74...  797776110773
#
#             upc
# 0  033977045743
# 1  033977045743
# 2  033977045743
# 3  033977045743
# 4  033977045743

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   brand             41188 non-null  object
#  1   colors            41188 non-null  object
#  2   sizes             41188 non-null  object
#  3   prices.amountMax  41188 non-null  float64
#  4   imageURLs         41188 non-null  object
#  5   ean               41188 non-null  object
#  6   upc               41188 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 2.2+ MB

# %%
# renombrar

df=df.rename(columns={'colors':'color', 'sizes':'size', 'prices.amountMax':'price', 'imageURLs':'url'})
df.head()
# Out:
#       brand color size  price  \
# 0  MUK LUKS  Grey   10   47.0
# 1  MUK LUKS  Grey    7   47.0
# 2  MUK LUKS  Grey    6   47.0
# 3  MUK LUKS  Grey    9   47.0
# 4  MUK LUKS  Grey    8   47.0
#
#                                                  url           ean  \
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540370
# 2  https://i5.walmartimages.com/asr/421de5d5-3a74...  797776092321
# 3  https://i5.walmartimages.com/asr/421de5d5-3a74...  701197194311
# 4  https://i5.walmartimages.com/asr/421de5d5-3a74...  797776110773
#
#             upc
# 0  033977045743
# 1  033977045743
# 2  033977045743
# 3  033977045743
# 4  033977045743

# %% [markdown]
# **conexion a PostGres e insercion de datos**

# %%
#!sudo -u iudh createdb barcodes

SCHEMA='barcodes'

str_conn=f'postgresql+psycopg2://iudh:password@localhost:5432/{SCHEMA}'

# %%
Base=declarative_base()

class Barcodes(Base):
    __tablename__='barcodes'
    __table_args__={'schema': SCHEMA}
    
    id=Column(Integer(), primary_key=True, autoincrement=True)
    brand=Column(Text())
    color=Column(Text())
    size=Column(Text())
    price=Column(Text())
    url=Column(Text())
    ean=Column(Text())
    upc=Column(Text())

# %%
sql=ToSQL(str_conn, SCHEMA, Barcodes)
sql.borra_tablas()
sql.crea_tablas()
# Out:
# Borrando tabla...
# Creando tabla...

# %%
sql.rellena_tablas(df)
# Out:
# Comiteado

# %%
df_codes=sql.show_df()
df_codes.head()
# Out:
#    id     brand color size price  \
# 0   1  MUK LUKS  Grey   10  47.0
# 1   2  MUK LUKS  Grey    7  47.0
# 2   3  MUK LUKS  Grey    6  47.0
# 3   4  MUK LUKS  Grey    9  47.0
# 4   5  MUK LUKS  Grey    8  47.0
#
#                                                  url           ean  \
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540370
# 2  https://i5.walmartimages.com/asr/421de5d5-3a74...  797776092321
# 3  https://i5.walmartimages.com/asr/421de5d5-3a74...  701197194311
# 4  https://i5.walmartimages.com/asr/421de5d5-3a74...  797776110773
#
#             upc
# 0  033977045743
# 1  033977045743
# 2  033977045743
# 3  033977045743
# 4  033977045743

# %% [markdown]
# # Generador de codigos de barras (imagenes)

# %%
from barcode import EAN13
from barcode.writer import ImageWriter

# %%
df_codes.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      41188 non-null  int64
#  1   brand   41188 non-null  object
#  2   color   41188 non-null  object
#  3   size    41188 non-null  object
#  4   price   41188 non-null  object
#  5   url     41188 non-null  object
#  6   ean     41188 non-null  object
#  7   upc     41188 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 99.5 MB

# %%
# se crean 20 imagenes de codigos de barras

for i in range(20):
    with open(f'../images/barcodes/code_{i}.jpeg', 'wb') as f:
        EAN13(df_codes.ean[i], writer=ImageWriter()).write(f)

# %% [markdown]
# # Proceso de uso:
#
# + Captura imagen por webcam de un codigo de barras
# + Decodifica codigo de barras
# + Busca el producto en la base de datos
# + Busca productos similares

# %%
import cv2
from PIL import Image
from pyzbar.pyzbar import decode

import ast

import requests

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# captura por camara

def captura():
    cam=cv2.VideoCapture(0)
    while 1:
        ret, frame=cam.read()
        cv2.imshow('Captura', frame)
        
        if ret==False: break
        
        key=cv2.waitKey(1)
        
        if key%256==27: break # tecla ESC
            
        elif key%256==32: # tecla SPACE
            img_name='../images/capturas/codigo.png'
            cv2.imwrite(img_name, frame)
            print('Captura guardada.')
            break
            
    cam.release()
    cv2.destroyAllWindows()
    plt.imshow(plt.imread(img_name));

# %%
# decodifica codigo de barras

def decodifica():
    codigo=decode(Image.open('../images/capturas/codigo.png'))[0][0]
    return codigo

# %%
# conexion db

def base_datos():
    return sql.show_df()

# %%
# busqueda elemento en db

def elemento(df, codigo):
    
    elem=df.loc[df.ean==str(ast.literal_eval(codigo.decode('utf8')))[0:-1]]
    
    display(elem)
    
    res=requests.get(elem.url[elem.index[0]], stream=True)
    img=Image.open(res.raw)
    
    plt.imshow(img)
    plt.show();
    
    return elem

# %%
# busqueda de elementos similares

def busqueda_similares(df, elem, campo):
    
    productos=df.loc[df[campo]==elem[campo][elem.index[0]]]
    
    return productos

# %%
# funcion para fotos de similares

def fotos(productos):
    
    urls=productos.url.tolist()
    
    for e in urls:
        try:
            res=requests.get(e, stream=True)
            img=Image.open(res.raw)

            plt.imshow(img)
            plt.show();
            
        except:
            print('No hay foto.')

# %% [markdown]
# **Captura por webcam**

# %%
captura() # captura el codigo de barras
# Out:
# Captura guardada.

# %% [markdown]
# **Decodifica y llama a base de datos**

# %%
codigo=decodifica()

data=base_datos()

# %% [markdown]
# **Elemento buscado**

# %%
elem=elemento(data, codigo)
# Out:
#    id     brand color size price  \
# 0   1  MUK LUKS  Grey   10  47.0
#
#                                                  url           ean  \
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363
#
#             upc
# 0  033977045743

# %% [markdown]
# **Busqueda elementos similares**

# %%
busqueda_similares(data, elem, 'brand').tail()
# Out:
#       id     brand         color size price  \
# 338  320  MUK LUKS          Grey   11  59.0
# 339  321  MUK LUKS    Dark Brown   11  59.0
# 340  322  MUK LUKS      Moccasin   11  59.0
# 341  323  MUK LUKS    Light Gray   11  59.0
# 342  324  MUK LUKS  Medium Brown   11  59.0
#
#                                                    url            ean  \
# 338  https://i5.walmartimages.com/asr/329a817d-1213...  8935101200276
# 339  https://i5.walmartimages.com/asr/329a817d-1213...  8935101200313
# 340  https://i5.walmartimages.com/asr/329a817d-1213...  8935101200320
# 341  https://i5.walmartimages.com/asr/329a817d-1213...  8935101200429
# 342  https://i5.walmartimages.com/asr/329a817d-1213...  8935104613011
#
#               upc
# 338  033977166448
# 339  033977166448
# 340  033977166448
# 341  033977166448
# 342  033977166448

# %%
busqueda_similares(data, elem, 'price').tail()
# Out:
#    id     brand color size price  \
# 0   1  MUK LUKS  Grey   10  47.0
# 1   2  MUK LUKS  Grey    7  47.0
# 2   3  MUK LUKS  Grey    6  47.0
# 3   4  MUK LUKS  Grey    9  47.0
# 4   5  MUK LUKS  Grey    8  47.0
#
#                                                  url           ean  \
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540370
# 2  https://i5.walmartimages.com/asr/421de5d5-3a74...  797776092321
# 3  https://i5.walmartimages.com/asr/421de5d5-3a74...  701197194311
# 4  https://i5.walmartimages.com/asr/421de5d5-3a74...  797776110773
#
#             upc
# 0  033977045743
# 1  033977045743
# 2  033977045743
# 3  033977045743
# 4  033977045743

# %%
busqueda_similares(data, elem, 'color').tail()
# Out:
#           id               brand color size  price  \
# 12513  10929  journee collection  Grey    7  74.99
# 12517  10932  journee collection  Grey  7.5  74.99
# 12520  10935  journee collection  Grey    8  74.99
# 12524  10938  journee collection  Grey  8.5  74.99
# 12528  10941  journee collection  Grey    9  74.99
#
#                                                      url           ean  \
# 12513  https://media.kohlsimg.com/is/image/kohls/2671...  799439066861
# 12517  https://media.kohlsimg.com/is/image/kohls/2671...   58478109053
# 12520  https://media.kohlsimg.com/is/image/kohls/2671...   60915959206
# 12524  https://media.kohlsimg.com/is/image/kohls/2671...   64541649722
# 12528  https://media.kohlsimg.com/is/image/kohls/2671...  793573169990
#
#                                                      upc
# 12513  870191628228,870191628310,870191628136,8701916...
# 12517  870191628228,870191628310,870191628136,8701916...
# 12520  870191628228,870191628310,870191628136,8701916...
# 12524  870191628228,870191628310,870191628136,8701916...
# 12528  870191628228,870191628310,870191628136,8701916...

# %%
productos=busqueda_similares(data, elem, 'size')

display(productos.head())

fotos(productos.iloc[7:15])
# Out:
#       id       brand       color size  price  \
# 0      1    MUK LUKS        Grey   10   47.0
# 5      6    MUK LUKS        Grey   10  35.25
# 8   1815  Riverberry  Gold Snake   10  24.99
# 11    11    MUK LUKS       Black   10  24.75
# 17    16    MUK LUKS        Grey   10   33.0
#
#                                                   url           ean  \
# 0   https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363
# 5   https://i5.walmartimages.com/asr/421de5d5-3a74...  797776110797
# 8   https://i5.walmartimages.com/asr/258c2405-50a0...  666027182206
# 11  https://i5.walmartimages.com/asr/950d38a5-0113...  701197247505
# 17  https://i5.walmartimages.com/asr/5e137bc3-c900...  797776111084
#
#              upc
# 0   033977045743
# 5   033977045743
# 8   889509027592
# 11  033977045903
# 17  033977045958

# %% [markdown]
# # Sql
#
# Primero, cargar datos en base de datos...

# %% [raw]
# !pip3 install mysql-connector-python

# %%
import mysql.connector as conn

# %%
# crea una base de datos

crea_db=conn.connect(host='localhost', user='root', passwd='password')

cursor=crea_db.cursor()

cursor.execute('drop database if exists productos')
cursor.execute('create database productos')

# %%
# check

cursor.execute('show databases')
for x in cursor:
    print(x)
# Out:
# ('Apps',)
# ('information_schema',)
# ('mydb',)
# ('mysql',)
# ('performance_schema',)
# ('productos',)
# ('publications',)
# ('sys',)

# %%
# conecta a sql

db=conn.connect(host='localhost', user='root', passwd='password', database='productos')

cursor=db.cursor()

# %%
# crea una tabla

cursor.execute('drop table if exists zapatos')

tabla='''
        create table zapatos(
            id int,
            brand varchar(50),
            color varchar(50),
            size varchar(50),
            price float,
            url varchar(10000),
            ean varchar(50),
            upc varchar(5000)
        );

'''

cursor.execute(tabla)

# %%
# check

cursor.execute('show tables')
for x in cursor:
    print(x)
# Out:
# ('zapatos',)

# %%
df['id']=[i for i in range(len(df))]

df.head()
# Out:
#       brand color size  price  \
# 0  MUK LUKS  Grey   10   47.0
# 1  MUK LUKS  Grey    7   47.0
# 2  MUK LUKS  Grey    6   47.0
# 3  MUK LUKS  Grey    9   47.0
# 4  MUK LUKS  Grey    8   47.0
#
#                                                  url           ean  \
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540370
# 2  https://i5.walmartimages.com/asr/421de5d5-3a74...  797776092321
# 3  https://i5.walmartimages.com/asr/421de5d5-3a74...  701197194311
# 4  https://i5.walmartimages.com/asr/421de5d5-3a74...  797776110773
#
#             upc  id
# 0  033977045743   0
# 1  033977045743   1
# 2  033977045743   2
# 3  033977045743   3
# 4  033977045743   4

# %%
# insert query

for i in range(len(df)):
    
    insert_query='insert into {} ({}) values {};'\
                 .format('zapatos', ','.join(df.columns), tuple(df.iloc[i].values))
    
    cursor.execute(insert_query)
    
db.commit()

# %%
# check

cursor.execute('select * from zapatos limit 1')
for x in cursor:
    print(x)
# Out:
# (0, 'MUK LUKS', 'Grey', '10', 47.0, 'https://i5.walmartimages.com/asr/421de5d5-3a74-4ca2-ae91-a75787f7da41_1.375e3cf74dc82303ce37bdf6a9742610.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/202d5a0e-b2aa-4d47-b63c-661fc3f9cd69_1.a61c1848859953067192fb2ce1c4f916.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/55a10ffd-de74-406b-8aa5-ae5be3569ee3_1.4b179b9702f0076cdf701afd0e7dcda2.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/138e9ecf-fac8-4e9d-946a-7ca33dfa46aa_1.e4211c14f2a6ecf891e3d440402b5f82.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/8c6c1ee4-7708-4d45-b48a-b30f974a5f2f_1.857088c50496451990583941d955218d.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/a486d1cf-f2b5-49ca-b0f8-3e2db896c51c_1.de1c99ac6fdfcf3dc3ddbd9c1c6c72b1.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF', '725177540363', '033977045743')

# %%
cursor.execute('select * from zapatos')

data=cursor.fetchall()

# %%
df=pd.DataFrame(data, columns=cursor.column_names)

df.head()
# Out:
#    id     brand color size  price  \
# 0   0  MUK LUKS  Grey   10   47.0
# 1   1  MUK LUKS  Grey    7   47.0
# 2   2  MUK LUKS  Grey    6   47.0
# 3   3  MUK LUKS  Grey    9   47.0
# 4   4  MUK LUKS  Grey    8   47.0
#
#                                                  url           ean  \
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540370
# 2  https://i5.walmartimages.com/asr/421de5d5-3a74...  797776092321
# 3  https://i5.walmartimages.com/asr/421de5d5-3a74...  701197194311
# 4  https://i5.walmartimages.com/asr/421de5d5-3a74...  797776110773
#
#             upc
# 0  033977045743
# 1  033977045743
# 2  033977045743
# 3  033977045743
# 4  033977045743

# %%
def base_datos_sql(cursor, tabla):
    cursor.execute(f'select * from {tabla}')
    
    df=pd.DataFrame(cursor.fetchall(), columns=cursor.column_names)
    
    return df

# %%
codigo=decodifica()

data=base_datos_sql(cursor, 'zapatos')

elem=elemento(data, codigo)
# Out:
#    id     brand color size  price  \
# 0   0  MUK LUKS  Grey   10   47.0
#
#                                                  url           ean  \
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363
#
#             upc
# 0  033977045743

# %%
busqueda_similares(data, elem, 'brand').tail()
# Out:
#       id     brand         color size  price  \
# 319  319  MUK LUKS          Grey   11   59.0
# 320  320  MUK LUKS    Dark Brown   11   59.0
# 321  321  MUK LUKS      Moccasin   11   59.0
# 322  322  MUK LUKS    Light Gray   11   59.0
# 323  323  MUK LUKS  Medium Brown   11   59.0
#
#                                                    url            ean  \
# 319  https://i5.walmartimages.com/asr/329a817d-1213...  8935101200276
# 320  https://i5.walmartimages.com/asr/329a817d-1213...  8935101200313
# 321  https://i5.walmartimages.com/asr/329a817d-1213...  8935101200320
# 322  https://i5.walmartimages.com/asr/329a817d-1213...  8935101200429
# 323  https://i5.walmartimages.com/asr/329a817d-1213...  8935104613011
#
#               upc
# 319  033977166448
# 320  033977166448
# 321  033977166448
# 322  033977166448
# 323  033977166448
